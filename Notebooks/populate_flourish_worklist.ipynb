# %%
import os
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
# ContactLocator Structure
CaregiverContact.objects.first().__dict__
# Out:
# {'_state': <django.db.models.base.ModelState at 0x7fc3eda424d0>,
#  'created': datetime.datetime(2022, 3, 8, 12, 33, 51, 6558, tzinfo=<UTC>),
#  'modified': datetime.datetime(2022, 3, 8, 12, 33, 51, 6569, tzinfo=<UTC>),
#  'user_created': 'gelija',
#  'user_modified': '',
#  'hostname_created': 'flourish',
#  'hostname_modified': 'flourish',
#  'revision': '',
#  'device_created': '99',
#  'device_modified': '99',
#  'id': UUID('0036bc14-391f-4508-a014-77154cc5dc43'),
#  'subject_identifier': 'B142-040990360-5',
#  'report_datetime': datetime.datetime(2022, 3, 8, 12, 33, 27, tzinfo=<UTC>),
#  'contact_type': 'phone_call',
#  'contact_datetime': datetime.datetime(2022, 3, 8, 12, 33, 32, tzinfo=<UTC>),
#  'call_reason': 'follow_up',
#  'call_reason_other': None,
#  'contact_success': 'Yes',
#  'contact_comment': 'Successful',
#  'call_rescheduled': None,
#  'reason_rescheduled': None}

# %%
WorkList.objects.first().__dict__
# Out:
# {'_state': <django.db.models.base.ModelState at 0x7fc3eda42830>,
#  'created': datetime.datetime(2021, 4, 29, 9, 38, 31, 921661, tzinfo=<UTC>),
#  'modified': datetime.datetime(2021, 5, 4, 7, 31, 1, 984319, tzinfo=<UTC>),
#  'user_created': 'ckgathi',
#  'user_modified': 'flourish',
#  'hostname_created': 'flourish',
#  'hostname_modified': 'flourish',
#  'revision': '',
#  'device_created': '99',
#  'device_modified': '99',
#  'id': UUID('00084ad4-918d-42e5-8a81-8cfff7a90e81'),
#  'site_id': 40,
#  'slug': 'b001496-0',
#  'subject_identifier': 'B001496-0',
#  'study_maternal_identifier': 'B001496-0',
#  'report_datetime': None,
#  'assigned': 'gelija',
#  'date_assigned': datetime.date(2021, 5, 4),
#  'prev_study': 'Mashi',
#  'is_called': False,
#  'called_datetime': None,
#  'visited': False,
#  'consented': False}

# %%
import datetime

contact_details = CaregiverLocator.objects.filter(study_maternal_identifier__startswith='066')



for contact in contact_details:
    PreFlourishWorkList.objects.update_or_create(
        subject_identifier = contact.subject_identifier,
        study_maternal_identifier = contact.study_maternal_identifier,
        prev_study = 'BCCP',
        user_created = 'flourish',
        report_datetime = datetime.datetime.now()
        
    )
# Out:
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:31.717740) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1309: RuntimeWarning: DateTimeField PreFlourishCall.scheduled received a naive datetime (2022-08-01 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:31.842004) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:31.908930) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:31.974438) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:32.039670) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:32.104444) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:32.168990) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:32.234261) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:32.299210) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:32.366250) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:32.431359) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:32.496703) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:32.565230) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:32.636793) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:32.727549) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:32.805836) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:32.900017) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:32.992613) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:33.065737) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:33.134867) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:33.202539) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:33.271912) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:33.340007) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:33.408212) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:33.477718) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:33.547198) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:33.615103) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:33.684203) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:33.752750) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:33.820377) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:33.888057) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:33.955864) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:34.023582) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:34.105053) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:34.176028) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:34.269241) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:34.370833) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:34.467178) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:34.562142) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:34.629553) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:34.696690) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:34.764247) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:34.831299) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:34.898588) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:34.968685) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:35.037313) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:35.133055) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:35.198719) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:35.263319) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:35.328031) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:35.392895) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:35.457731) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:35.522205) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:35.610854) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:35.708891) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:35.809929) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:35.904042) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:35.997161) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:36.063919) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:36.128666) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:36.193362) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:36.257943) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:36.322922) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:36.388040) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:36.452923) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:36.517415) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:36.582065) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:36.646987) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:36.713119) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:36.779906) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:36.844894) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:36.910599) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:36.975458) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:37.055969) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:37.152097) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:37.230259) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:37.308211) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:37.404302) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:37.502310) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:37.568181) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:37.632816) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:37.697465) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:37.761760) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:37.827800) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:37.893525) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:37.958602) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:38.022973) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:38.087594) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:38.187439) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:38.254837) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:38.319662) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:38.384288) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:38.449033) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:38.513759) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:38.590106) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:38.662695) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:38.754535) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:38.846640) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:38.942694) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:39.038719) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:39.113097) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:39.179375) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:39.246325) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:39.311377) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:39.376483) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:39.441749) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:39.506382) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:39.570923) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:39.635242) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:39.699649) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:39.764422) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:39.828943) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:39.893423) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:39.958233) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:40.024398) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:40.090256) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:40.155756) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:40.248592) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:40.323828) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:40.388370) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:40.485714) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:40.551069) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:40.642586) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:40.707450) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:40.773635) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:40.838887) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:40.903634) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:40.968181) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:41.032676) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:41.097597) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:41.164608) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:41.229780) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:41.294662) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:41.359598) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:41.424606) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:41.489570) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:41.554726) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:41.619185) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:41.683935) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:41.763885) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:21:41.856392) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# ...
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:45.659502) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:45.723984) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:45.789662) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:45.885727) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:45.956403) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:46.024639) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:46.090601) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:46.155483) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:46.220810) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:46.284936) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:46.349737) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:46.413878) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:46.479238) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:46.543818) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:46.608770) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:46.673466) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:46.741097) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:46.806252) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:46.888126) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:46.972806) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:47.048163) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:47.115185) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:47.210890) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:47.306075) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:47.374025) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:47.438628) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:47.503500) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:47.567962) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:47.632535) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:47.697168) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:47.762180) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:47.826854) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:47.891261) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:47.957897) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:48.022869) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:48.088107) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:48.153074) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:48.220181) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:48.285347) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:48.381056) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:48.462851) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:48.557173) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:48.652197) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:48.745205) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:48.840087) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:48.936054) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /Users/mchawawa/opt/anaconda3/envs/flourish/lib/python3.10/site-packages/django/db/models/fields/__init__.py:1367: RuntimeWarning: DateTimeField PreFlourishWorkList.report_datetime received a naive datetime (2022-08-01 11:22:49.003947) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"

# %%
PreFlourishWorkList.objects.first().__dict__
# Out:
# {'_state': <django.db.models.base.ModelState at 0x7fc2db0dc700>,
#  'created': datetime.datetime(2022, 6, 17, 12, 24, 31, 862853, tzinfo=<UTC>),
#  'modified': datetime.datetime(2022, 6, 17, 12, 24, 31, 862862, tzinfo=<UTC>),
#  'user_created': 'moses',
#  'user_modified': '',
#  'hostname_created': 'cyborg.local',
#  'hostname_modified': 'cyborg.local',
#  'revision': '',
#  'device_created': '01',
#  'device_modified': '01',
#  'id': UUID('0066b60a-4703-43d2-b0b1-3722b39d9093'),
#  'site_id': 40,
#  'slug': '066-17260024-4',
#  'subject_identifier': '066-17260024-4',
#  'study_maternal_identifier': '066-17260024-4',
#  'report_datetime': None,
#  'assigned': None,
#  'date_assigned': None,
#  'prev_study': 'BCCP',
#  'is_called': False,
#  'called_datetime': None,
#  'visited': False,
#  'consented': False}
